# %%
import numpy as np
import chess
import chess.pgn
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import time

# %%
def fen_to_numeric(char):
    
    # Switches fen characters to numeric piece values
    # White pieces are positive numbers and black pieces are negative numbers
    #
    # argument : A non-numeric character in a FEN string
    # return   : Numeric value of input piece
    
    switcher = {
        'r' : -5,
        'n' : -3,
        'b' : -4,
        'q' : -9,
        'k' : -10,
        'p' : -1,
        'R' : 5,
        'N' : 3,
        'B' : 4,
        'Q' : 9,
        'K' : 10,
        'P' : 1,
    }
    return(switcher.get(char))

def get_board_state(board): 
    
    # Takes a chess board and converts the PGN to FEN notation. Then subs the 
    # FEN characters for the value of each piece and splits the result into an array
    #
    # argument : chess board object
    # return   : input array for NN

    shredder_fen = list((board.shredder_fen().split(" ")[0]).replace("/",""))
    numeric_fen = []
    for char in shredder_fen:
        if(char.isdigit()): # empty squares between pieces: add zeros
            for i in range(int(char)):
                numeric_fen.append(0)
        else: # convert piece notation to numeric value
            numeric_fen.append(fen_to_numeric(char))
    
    # Whose turn is it?
    if(board.turn == True):
        numeric_fen + [1] # White to move
    else:
        numeric_fen + [0] # Black to move
    
    # Is the king in check?
    if(board.is_check() == True):
        numeric_fen += [1] # Yes
    else:
        numeric_fen += [0] # No
    
    # Is queenside castling available for player?
    if(board.has_queenside_castling_rights(board.turn)):
        numeric_fen += [1] # Yes
    else:
        numeric_fen += [0] # No
        
    # Is kingside castling available for player?
    if(board.has_kingside_castling_rights(board.turn)):
        numeric_fen += [1] # Yes
    else:
        numeric_fen += [0] # No
        
    # Is queenside castling available for opponent?
    if(board.has_queenside_castling_rights(not(board.turn))):
        numeric_fen += [1] # Yes
    else:
        numeric_fen += [0] # No
        
    # Is kingside castling available for player?
    if(board.has_kingside_castling_rights(not(board.turn))):
        numeric_fen += [1] # Yes
    else:
        numeric_fen += [0] # No
        
    # How many turns have passed
    numeric_fen += [board.ply()]

    return(numeric_fen)

    # Who won?
#     if(board.has_kingside_castling_rights(not(board.turn))):
#         numeric_fen += [1] # Yes
#     else:
#         numeric_fen += [0] # No

#     return(numeric_fen)
    

def game_to_data(game, color, period):
    
    # Takes a chess game and processes it into a inputs to the NN
    # The board state is a numeric representation generated by get_board_state()
    # target_origin move is the space from which a piece is moved: target for first NN
    # target_dest move is the space to which a piece is moved: target for second NN
    #
    # argument : chess game object
    # return   : [flattened board states, target origin moves, target destination moves]
    
    # determine upper and lower bound to separate early, mid, and late game
    if period == 'early':
        lb = 0
        ub = 14
    elif period == 'mid':
        lb = 15
        ub = 40
    else:
        lb = 41
        ub = np.inf
    
    
    board_state = []
    target_origin = []
    target_dest = []
    board = game.board()
    
    # Who won?
    if(game.headers['Result'] == "1-0"):
        winner = [1]
    elif(game.headers['Result'] == "0-1"):
        winner = [-1]
    else:
        winner = [0]
    
    for move in game.mainline_moves():
        if(board.turn == color and lb <= board.ply() <= ub):
            board_state.append(get_board_state(board) + winner) # add the board state
            target_origin.append(move.from_square)
            target_dest.append(move.to_square)
        board.push(move) # play the next move on the board
    
    return board_state, target_origin, target_dest

def aggregate_game_data(game1, game2):
    
    # Combines game data 
    #
    # argument : chess game object
    # return   : [flattened board states, target origin moves, target destination moves]
    
    X1 = game1[0]
    X2 = game2[0]
    y1 = game1[1]
    y2 = game2[1]
    z1 = game1[2]
    z2 = game2[2]

    return X1 + X2, y1 + y2, z1 + z2

def conv_nn_data(pgn_games, color, period):
    
    # Wrapper for the other functions. Goes through the list of games and converts the
    # games to training and target data
    #
    # argument : list of chess game objects
    # return   : [flattened board states, target origin moves, target destination moves]

    nn_data = game_to_data(pgn_games[0], color, period)
    pgn_games = pgn_games[1:]
    
    for game in pgn_games:
        nn_data = aggregate_game_data(nn_data, game_to_data(game, color, period))
    
    return np.array(nn_data[0]), np.array(nn_data[1]), np.array(nn_data[2]) # inputs, target1, target2

def read_pgn_from_file(file):
    
    # Reads in all of the games in PGN form from a .pgn file and saves them as a list
    #
    # argument : .pgn file path
    # return   : list of chess game objects
    
    pgn = open(file)
    pgn_games = []
    while(True):
        game = chess.pgn.read_game(pgn)
        if(game == None):
            break
        pgn_games.append(game)
    return(pgn_games)

def mod_MaP_inputs(X, y1):

    # Used for the Move-a-Piece NN. Adds the selected piece (y1 target) as an input to the second NN
    #
    # argument : SaP input array
    # return   : MaP input Array (72 elements per row)
    
    MaP_input = []
    for i in range(len(X)):
        MaP_input.append(np.append(X[i], y1[i]))
    return np.array(MaP_input)

# %%
pgn_games = read_pgn_from_file("Documents/metis/NN_Chess_Engine/fics_games/fics_2020.pgn")

# %%
# extract inputs from a list of PGN games
game_num = 10000

X1_white_early, y1_white_early, y2_white_early = conv_nn_data(pgn_games[:game_num], color = True, period = 'early')
X1_white_mid, y1_white_mid, y2_white_mid = conv_nn_data(pgn_games[:game_num], color = True, period = 'mid')
X1_white_late, y1_white_late, y2_white_late = conv_nn_data(pgn_games[:game_num], color = True, period = 'late')

X2_white_early = mod_MaP_inputs(X1_white_early, y1_white_early)
X2_white_mid = mod_MaP_inputs(X1_white_mid, y1_white_mid)
X2_white_late = mod_MaP_inputs(X1_white_late, y1_white_late)

# convert the targets to 64-element arrays to contain the decision space of the board (8 x 8 squares)
y1_white_early = tf.keras.utils.to_categorical(y1_white_early, num_classes=64)
y2_white_early = tf.keras.utils.to_categorical(y2_white_early, num_classes=64)

y1_white_mid= tf.keras.utils.to_categorical(y1_white_mid, num_classes=64)
y2_white_mid = tf.keras.utils.to_categorical(y2_white_mid, num_classes=64)

y1_white_late = tf.keras.utils.to_categorical(y1_white_late, num_classes=64)
y2_white_late = tf.keras.utils.to_categorical(y2_white_late, num_classes=64)

# %%
SaP_model = keras.Sequential([
    keras.layers.Dense(units=1024, input_shape=(71, ), activation="relu", name="hidden_layer1"),
    keras.layers.Dropout(0.2),
#     keras.layers.Dense(units=512, activation="relu", name="hidden_layer2"),
#     keras.layers.Dropout(0.2),
    keras.layers.Dense(units=64, activation="softmax", name="output_layer")
])

SaP_model.compile(optimizer="nadam", loss="categorical_crossentropy", metrics=["acc"])

MaP_model = keras.Sequential([
    keras.layers.Dense(units=1024, input_shape=(72, ), activation="relu", name="hidden_layer1"),
    keras.layers.Dropout(0.2),
#     keras.layers.Dense(units=512, activation="relu", name="hidden_layer2"),
#     keras.layers.Dropout(0.2),
    keras.layers.Dense(units=64, activation="softmax", name="output_layer")
])

MaP_model.compile(optimizer="nadam", loss="categorical_crossentropy", metrics=["acc"])

# %%
SaP_white_early, SaP_white_mid, SaP_white_late, SaP_black_early, SaP_black_mid, SaP_white_late = SaP_model, SaP_model, SaP_model, SaP_model, SaP_model, SaP_model
MaP_white_early, MaP_white_mid, MaP_white_late, MaP_black_early, MaP_black_mid, MaP_white_late = MaP_model, MaP_model, MaP_model, MaP_model, MaP_model, MaP_model

# %%
SaP_white_early.fit(x=X1_white_early, y=y1_white_early, epochs=50, validation_split=.25, verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=8, verbose=1, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=.5, patience=3, verbose=1),
    ])

SaP_white_mid.fit(x=X1_white_mid, y=y1_white_mid, epochs=50, validation_split=.25, verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=8, verbose=1, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=.5, patience=3, verbose=1),
    ])

SaP_white_late.fit(x=X1_white_late, y=y1_white_late, epochs=50, validation_split=.25, verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=8, verbose=1, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=.5, patience=3, verbose=1),
    ])

MaP_white_early.fit(x=X2_white_early, y=y2_white_early, epochs=50, validation_split=.25, verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=8, verbose=1, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=.5, patience=3, verbose=1),
    ])

MaP_white_mid.fit(x=X2_white_mid, y=y2_white_mid, epochs=50, validation_split=.25, verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=8, verbose=1, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=.5, patience=3, verbose=1),
    ])

MaP_white_late.fit(x=X2_white_late, y=y2_white_late, epochs=50, validation_split=.25, verbose=1,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=8, verbose=1, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=.5, patience=3, verbose=1),
    ])
# Out:
# Epoch 1/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.9677 - acc: 0.3967 - val_loss: 2.0152 - val_acc: 0.3573
# Epoch 2/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.6510 - acc: 0.4837 - val_loss: 1.7405 - val_acc: 0.4197
# Epoch 3/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.5333 - acc: 0.5130 - val_loss: 1.6145 - val_acc: 0.4896
# Epoch 4/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.4623 - acc: 0.5318 - val_loss: 1.5586 - val_acc: 0.5129
# Epoch 5/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.4127 - acc: 0.5436 - val_loss: 1.5323 - val_acc: 0.5174
# Epoch 6/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.3746 - acc: 0.5543 - val_loss: 1.5823 - val_acc: 0.5039
# Epoch 7/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.3455 - acc: 0.5623 - val_loss: 1.5932 - val_acc: 0.4798
# Epoch 8/50
# 1824/1837 [============================>.] - ETA: 0s - loss: 1.3163 - acc: 0.5682
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.3170 - acc: 0.5681 - val_loss: 1.5415 - val_acc: 0.5275
# Epoch 9/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.2179 - acc: 0.5992 - val_loss: 1.4702 - val_acc: 0.5459
# Epoch 10/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.1919 - acc: 0.6056 - val_loss: 1.4736 - val_acc: 0.5498
# Epoch 11/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.1756 - acc: 0.6099 - val_loss: 1.4740 - val_acc: 0.5495
# Epoch 12/50
# 1829/1837 [============================>.] - ETA: 0s - loss: 1.1576 - acc: 0.6150
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.1576 - acc: 0.6150 - val_loss: 1.4823 - val_acc: 0.5468
# Epoch 13/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.1077 - acc: 0.6315 - val_loss: 1.4511 - val_acc: 0.5574
# Epoch 14/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0937 - acc: 0.6329 - val_loss: 1.4577 - val_acc: 0.5560
# Epoch 15/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0840 - acc: 0.6361 - val_loss: 1.4632 - val_acc: 0.5582
# Epoch 16/50
# 1836/1837 [============================>.] - ETA: 0s - loss: 1.0805 - acc: 0.6383
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0805 - acc: 0.6383 - val_loss: 1.4540 - val_acc: 0.5608
# Epoch 17/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0459 - acc: 0.6475 - val_loss: 1.4557 - val_acc: 0.5592
# Epoch 18/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0419 - acc: 0.6484 - val_loss: 1.4512 - val_acc: 0.5619
# Epoch 19/50
# 1826/1837 [============================>.] - ETA: 0s - loss: 1.0365 - acc: 0.6511
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0365 - acc: 0.6510 - val_loss: 1.4567 - val_acc: 0.5629
# Epoch 20/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0241 - acc: 0.6539 - val_loss: 1.4510 - val_acc: 0.5631
# Epoch 21/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0192 - acc: 0.6556 - val_loss: 1.4539 - val_acc: 0.5622
# Epoch 22/50
# 1821/1837 [============================>.] - ETA: 0s - loss: 1.0160 - acc: 0.6566
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0162 - acc: 0.6563 - val_loss: 1.4563 - val_acc: 0.5636
# Epoch 23/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0092 - acc: 0.6578 - val_loss: 1.4525 - val_acc: 0.5639
# Epoch 24/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0072 - acc: 0.6590 - val_loss: 1.4482 - val_acc: 0.5637
# Epoch 25/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0047 - acc: 0.6592 - val_loss: 1.4518 - val_acc: 0.5645
# Epoch 26/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0045 - acc: 0.6633 - val_loss: 1.4525 - val_acc: 0.5657
# Epoch 27/50
# 1828/1837 [============================>.] - ETA: 0s - loss: 1.0013 - acc: 0.6609
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0010 - acc: 0.6609 - val_loss: 1.4499 - val_acc: 0.5660
# Epoch 28/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.9973 - acc: 0.6636 - val_loss: 1.4516 - val_acc: 0.5658
# Epoch 29/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.9978 - acc: 0.6615 - val_loss: 1.4523 - val_acc: 0.5643
# Epoch 30/50
# 1826/1837 [============================>.] - ETA: 0s - loss: 0.9977 - acc: 0.6625
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.9973 - acc: 0.6626 - val_loss: 1.4513 - val_acc: 0.5651
# Epoch 31/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.9968 - acc: 0.6625 - val_loss: 1.4516 - val_acc: 0.5654
# Epoch 32/50
# 1834/1837 [============================>.] - ETA: 0s - loss: 0.9949 - acc: 0.6636Restoring model weights from the end of the best epoch.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.9953 - acc: 0.6634 - val_loss: 1.4510 - val_acc: 0.5661
# Epoch 00032: early stopping
# Epoch 1/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 8.3208 - acc: 0.1703 - val_loss: 6.7835 - val_acc: 0.1864
# Epoch 2/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 6.5667 - acc: 0.1685 - val_loss: 5.7018 - val_acc: 0.1840
# Epoch 3/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 5.6424 - acc: 0.1648 - val_loss: 5.0437 - val_acc: 0.1816
# Epoch 4/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 5.0520 - acc: 0.1651 - val_loss: 4.6162 - val_acc: 0.1793
# Epoch 5/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 4.6607 - acc: 0.1643 - val_loss: 4.3260 - val_acc: 0.1806
# Epoch 6/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 4.3705 - acc: 0.1656 - val_loss: 4.1150 - val_acc: 0.1814
# Epoch 7/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 4.1740 - acc: 0.1661 - val_loss: 3.9537 - val_acc: 0.1834
# Epoch 8/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 4.0048 - acc: 0.1715 - val_loss: 3.8265 - val_acc: 0.1855
# Epoch 9/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 3.8770 - acc: 0.1729 - val_loss: 3.7219 - val_acc: 0.1874
# Epoch 10/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 3.7636 - acc: 0.1769 - val_loss: 3.6355 - val_acc: 0.1895
# Epoch 11/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 3.6699 - acc: 0.1792 - val_loss: 3.5620 - val_acc: 0.1930
# Epoch 12/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 3.5970 - acc: 0.1842 - val_loss: 3.4978 - val_acc: 0.1952
# Epoch 13/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 3.5282 - acc: 0.1877 - val_loss: 3.4424 - val_acc: 0.1974
# Epoch 14/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.4649 - acc: 0.1897 - val_loss: 3.3933 - val_acc: 0.2006
# Epoch 15/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.4159 - acc: 0.1948 - val_loss: 3.3492 - val_acc: 0.2029
# Epoch 16/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.3646 - acc: 0.1961 - val_loss: 3.3088 - val_acc: 0.2043
# Epoch 17/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.3213 - acc: 0.1996 - val_loss: 3.2725 - val_acc: 0.2076
# Epoch 18/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.2834 - acc: 0.2036 - val_loss: 3.2391 - val_acc: 0.2100
# Epoch 19/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.2494 - acc: 0.2050 - val_loss: 3.2086 - val_acc: 0.2116
# Epoch 20/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.2129 - acc: 0.2092 - val_loss: 3.1803 - val_acc: 0.2132
# Epoch 21/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.1789 - acc: 0.2128 - val_loss: 3.1539 - val_acc: 0.2157
# Epoch 22/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.1553 - acc: 0.2141 - val_loss: 3.1299 - val_acc: 0.2169
# Epoch 23/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.1245 - acc: 0.2161 - val_loss: 3.1074 - val_acc: 0.2182
# Epoch 24/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.1048 - acc: 0.2199 - val_loss: 3.0863 - val_acc: 0.2193
# Epoch 25/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.0764 - acc: 0.2200 - val_loss: 3.0665 - val_acc: 0.2207
# Epoch 26/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.0510 - acc: 0.2213 - val_loss: 3.0481 - val_acc: 0.2216
# Epoch 27/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 3.0280 - acc: 0.2258 - val_loss: 3.0307 - val_acc: 0.2230
# Epoch 28/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 3.0052 - acc: 0.2275 - val_loss: 3.0141 - val_acc: 0.2242
# Epoch 29/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.9920 - acc: 0.2277 - val_loss: 2.9986 - val_acc: 0.2255
# Epoch 30/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.9701 - acc: 0.2312 - val_loss: 2.9836 - val_acc: 0.2260
# Epoch 31/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.9542 - acc: 0.2318 - val_loss: 2.9692 - val_acc: 0.2270
# Epoch 32/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.9384 - acc: 0.2323 - val_loss: 2.9552 - val_acc: 0.2280
# Epoch 33/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.9198 - acc: 0.2334 - val_loss: 2.9421 - val_acc: 0.2295
# Epoch 34/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.9060 - acc: 0.2360 - val_loss: 2.9297 - val_acc: 0.2299
# Epoch 35/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.8904 - acc: 0.2371 - val_loss: 2.9180 - val_acc: 0.2318
# Epoch 36/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.8801 - acc: 0.2398 - val_loss: 2.9063 - val_acc: 0.2321
# Epoch 37/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.8608 - acc: 0.2408 - val_loss: 2.8954 - val_acc: 0.2334
# Epoch 38/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.8491 - acc: 0.2396 - val_loss: 2.8851 - val_acc: 0.2343
# Epoch 39/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.8349 - acc: 0.2424 - val_loss: 2.8750 - val_acc: 0.2353
# Epoch 40/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.8242 - acc: 0.2451 - val_loss: 2.8650 - val_acc: 0.2358
# Epoch 41/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.8128 - acc: 0.2463 - val_loss: 2.8558 - val_acc: 0.2374
# Epoch 42/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.7978 - acc: 0.2470 - val_loss: 2.8470 - val_acc: 0.2368
# Epoch 43/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.7886 - acc: 0.2477 - val_loss: 2.8384 - val_acc: 0.2380
# Epoch 44/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.7819 - acc: 0.2489 - val_loss: 2.8302 - val_acc: 0.2388
# Epoch 45/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.7660 - acc: 0.2516 - val_loss: 2.8222 - val_acc: 0.2399
# Epoch 46/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.7599 - acc: 0.2494 - val_loss: 2.8145 - val_acc: 0.2415
# Epoch 47/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.7482 - acc: 0.2534 - val_loss: 2.8070 - val_acc: 0.2421
# Epoch 48/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.7386 - acc: 0.2546 - val_loss: 2.7998 - val_acc: 0.2430
# Epoch 49/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.7306 - acc: 0.2549 - val_loss: 2.7926 - val_acc: 0.2434
# Epoch 50/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.7223 - acc: 0.2539 - val_loss: 2.7860 - val_acc: 0.2433
# Epoch 1/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 4.7932 - acc: 0.2143 - val_loss: 3.8524 - val_acc: 0.2675
# Epoch 2/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 4.0338 - acc: 0.2305 - val_loss: 3.5156 - val_acc: 0.2779
# Epoch 3/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.6926 - acc: 0.2422 - val_loss: 3.3191 - val_acc: 0.2859
# Epoch 4/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.4875 - acc: 0.2531 - val_loss: 3.1878 - val_acc: 0.2907
# Epoch 5/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.3326 - acc: 0.2643 - val_loss: 3.0912 - val_acc: 0.2945
# Epoch 6/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.2203 - acc: 0.2726 - val_loss: 3.0158 - val_acc: 0.2984
# Epoch 7/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.1348 - acc: 0.2775 - val_loss: 2.9560 - val_acc: 0.3005
# Epoch 8/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.0619 - acc: 0.2846 - val_loss: 2.9048 - val_acc: 0.3018
# Epoch 9/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.0020 - acc: 0.2894 - val_loss: 2.8610 - val_acc: 0.3035
# Epoch 10/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 2.9518 - acc: 0.2915 - val_loss: 2.8227 - val_acc: 0.3041
# Epoch 11/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 2.9054 - acc: 0.2964 - val_loss: 2.7903 - val_acc: 0.3054
# Epoch 12/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.8686 - acc: 0.2992 - val_loss: 2.7611 - val_acc: 0.3058
# Epoch 13/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.8262 - acc: 0.3026 - val_loss: 2.7348 - val_acc: 0.3065
# Epoch 14/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.7986 - acc: 0.3044 - val_loss: 2.7110 - val_acc: 0.3069
# Epoch 15/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.7690 - acc: 0.3067 - val_loss: 2.6895 - val_acc: 0.3078
# Epoch 16/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.7429 - acc: 0.3094 - val_loss: 2.6698 - val_acc: 0.3089
# Epoch 17/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.7195 - acc: 0.3110 - val_loss: 2.6524 - val_acc: 0.3098
# Epoch 18/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.6960 - acc: 0.3126 - val_loss: 2.6355 - val_acc: 0.3106
# Epoch 19/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.6732 - acc: 0.3145 - val_loss: 2.6203 - val_acc: 0.3108
# Epoch 20/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.6551 - acc: 0.3164 - val_loss: 2.6060 - val_acc: 0.3118
# Epoch 21/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.6412 - acc: 0.3170 - val_loss: 2.5932 - val_acc: 0.3116
# Epoch 22/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.6225 - acc: 0.3188 - val_loss: 2.5813 - val_acc: 0.3123
# Epoch 23/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.6065 - acc: 0.3200 - val_loss: 2.5695 - val_acc: 0.3133
# Epoch 24/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.5908 - acc: 0.3224 - val_loss: 2.5581 - val_acc: 0.3137
# Epoch 25/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.5771 - acc: 0.3236 - val_loss: 2.5479 - val_acc: 0.3143
# Epoch 26/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.5652 - acc: 0.3243 - val_loss: 2.5383 - val_acc: 0.3147
# Epoch 27/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.5538 - acc: 0.3250 - val_loss: 2.5297 - val_acc: 0.3151
# Epoch 28/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.5401 - acc: 0.3273 - val_loss: 2.5207 - val_acc: 0.3157
# Epoch 29/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.5288 - acc: 0.3274 - val_loss: 2.5118 - val_acc: 0.3161
# Epoch 30/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.5171 - acc: 0.3283 - val_loss: 2.5036 - val_acc: 0.3166
# Epoch 31/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.5067 - acc: 0.3293 - val_loss: 2.4962 - val_acc: 0.3171
# Epoch 32/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4978 - acc: 0.3302 - val_loss: 2.4882 - val_acc: 0.3179
# Epoch 33/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4829 - acc: 0.3313 - val_loss: 2.4814 - val_acc: 0.3190
# Epoch 34/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4771 - acc: 0.3320 - val_loss: 2.4741 - val_acc: 0.3190
# Epoch 35/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4673 - acc: 0.3330 - val_loss: 2.4672 - val_acc: 0.3197
# Epoch 36/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4597 - acc: 0.3356 - val_loss: 2.4609 - val_acc: 0.3201
# Epoch 37/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4497 - acc: 0.3342 - val_loss: 2.4545 - val_acc: 0.3205
# Epoch 38/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4412 - acc: 0.3354 - val_loss: 2.4486 - val_acc: 0.3211
# Epoch 39/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4309 - acc: 0.3367 - val_loss: 2.4428 - val_acc: 0.3217
# Epoch 40/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4204 - acc: 0.3373 - val_loss: 2.4374 - val_acc: 0.3224
# Epoch 41/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4157 - acc: 0.3377 - val_loss: 2.4318 - val_acc: 0.3228
# Epoch 42/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4101 - acc: 0.3388 - val_loss: 2.4262 - val_acc: 0.3232
# Epoch 43/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.4033 - acc: 0.3396 - val_loss: 2.4212 - val_acc: 0.3243
# Epoch 44/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.3935 - acc: 0.3399 - val_loss: 2.4161 - val_acc: 0.3247
# Epoch 45/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.3878 - acc: 0.3414 - val_loss: 2.4111 - val_acc: 0.3250
# Epoch 46/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.3789 - acc: 0.3423 - val_loss: 2.4062 - val_acc: 0.3256
# Epoch 47/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.3758 - acc: 0.3425 - val_loss: 2.4017 - val_acc: 0.3259
# Epoch 48/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.3677 - acc: 0.3427 - val_loss: 2.3973 - val_acc: 0.3255
# Epoch 49/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.3624 - acc: 0.3445 - val_loss: 2.3923 - val_acc: 0.3265
# Epoch 50/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 2.3570 - acc: 0.3444 - val_loss: 2.3877 - val_acc: 0.3265
# Epoch 1/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.5716 - acc: 0.5617 - val_loss: 1.2992 - val_acc: 0.6018
# Epoch 2/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 1.0887 - acc: 0.6855 - val_loss: 1.0973 - val_acc: 0.6708
# Epoch 3/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.9403 - acc: 0.7271 - val_loss: 0.9463 - val_acc: 0.7389
# Epoch 4/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.8457 - acc: 0.7541 - val_loss: 0.9328 - val_acc: 0.7373
# Epoch 5/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.7825 - acc: 0.7684 - val_loss: 0.8884 - val_acc: 0.7496
# Epoch 6/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.7370 - acc: 0.7809 - val_loss: 0.8811 - val_acc: 0.7476
# Epoch 7/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.6976 - acc: 0.7900 - val_loss: 0.8258 - val_acc: 0.7777
# Epoch 8/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.6768 - acc: 0.7971 - val_loss: 0.8398 - val_acc: 0.7800
# Epoch 9/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.6493 - acc: 0.8024 - val_loss: 0.8261 - val_acc: 0.7859
# Epoch 10/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.6232 - acc: 0.8103 - val_loss: 0.8256 - val_acc: 0.7866
# Epoch 11/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.6074 - acc: 0.8153 - val_loss: 0.8363 - val_acc: 0.7905
# Epoch 12/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.5914 - acc: 0.8193 - val_loss: 0.8573 - val_acc: 0.7835
# Epoch 13/50
# 1837/1837 [==============================] - ETA: 0s - loss: 0.5781 - acc: 0.8232
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.5781 - acc: 0.8232 - val_loss: 0.8600 - val_acc: 0.7896
# Epoch 14/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.4826 - acc: 0.8502 - val_loss: 0.7991 - val_acc: 0.8031
# Epoch 15/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.4588 - acc: 0.8575 - val_loss: 0.8006 - val_acc: 0.8090
# Epoch 16/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.4482 - acc: 0.8582 - val_loss: 0.7959 - val_acc: 0.8129
# Epoch 17/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.4369 - acc: 0.8630 - val_loss: 0.8218 - val_acc: 0.8109
# Epoch 18/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.4239 - acc: 0.8669 - val_loss: 0.8192 - val_acc: 0.8073
# Epoch 19/50
# 1824/1837 [============================>.] - ETA: 0s - loss: 0.4183 - acc: 0.8679
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.4181 - acc: 0.8680 - val_loss: 0.8092 - val_acc: 0.8108
# Epoch 20/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.3730 - acc: 0.8804 - val_loss: 0.8016 - val_acc: 0.8204
# Epoch 21/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.3613 - acc: 0.8867 - val_loss: 0.8027 - val_acc: 0.8218
# Epoch 22/50
# 1833/1837 [============================>.] - ETA: 0s - loss: 0.3562 - acc: 0.8863
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.3561 - acc: 0.8863 - val_loss: 0.8142 - val_acc: 0.8163
# Epoch 23/50
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.3326 - acc: 0.8942 - val_loss: 0.7981 - val_acc: 0.8226
# Epoch 24/50
# 1817/1837 [============================>.] - ETA: 0s - loss: 0.3325 - acc: 0.8964Restoring model weights from the end of the best epoch.
# 1837/1837 [==============================] - 5s 3ms/step - loss: 0.3320 - acc: 0.8964 - val_loss: 0.8060 - val_acc: 0.8199
# Epoch 00024: early stopping
# Epoch 1/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 4.6841 - acc: 0.1805 - val_loss: 3.5807 - val_acc: 0.1999
# Epoch 2/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 3.4542 - acc: 0.2032 - val_loss: 3.2365 - val_acc: 0.2251
# Epoch 3/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 3.1589 - acc: 0.2320 - val_loss: 3.0671 - val_acc: 0.2447
# Epoch 4/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.9936 - acc: 0.2536 - val_loss: 2.9622 - val_acc: 0.2598
# Epoch 5/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.8758 - acc: 0.2713 - val_loss: 2.8902 - val_acc: 0.2705
# Epoch 6/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.7809 - acc: 0.2867 - val_loss: 2.8348 - val_acc: 0.2800
# Epoch 7/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.7112 - acc: 0.2983 - val_loss: 2.7959 - val_acc: 0.2887
# Epoch 8/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.6507 - acc: 0.3083 - val_loss: 2.7622 - val_acc: 0.2966
# Epoch 9/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.5992 - acc: 0.3166 - val_loss: 2.7374 - val_acc: 0.2996
# Epoch 10/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.5451 - acc: 0.3267 - val_loss: 2.7164 - val_acc: 0.3042
# Epoch 11/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.5100 - acc: 0.3330 - val_loss: 2.6990 - val_acc: 0.3083
# Epoch 12/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.4693 - acc: 0.3406 - val_loss: 2.6839 - val_acc: 0.3124
# Epoch 13/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.4359 - acc: 0.3466 - val_loss: 2.6728 - val_acc: 0.3144
# Epoch 14/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.4014 - acc: 0.3541 - val_loss: 2.6655 - val_acc: 0.3170
# Epoch 15/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.3731 - acc: 0.3582 - val_loss: 2.6500 - val_acc: 0.3192
# Epoch 16/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.3427 - acc: 0.3632 - val_loss: 2.6423 - val_acc: 0.3203
# Epoch 17/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.3207 - acc: 0.3685 - val_loss: 2.6402 - val_acc: 0.3190
# Epoch 18/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.2975 - acc: 0.3729 - val_loss: 2.6356 - val_acc: 0.3220
# Epoch 19/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.2726 - acc: 0.3783 - val_loss: 2.6336 - val_acc: 0.3239
# Epoch 20/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.2511 - acc: 0.3818 - val_loss: 2.6274 - val_acc: 0.3259
# Epoch 21/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.2320 - acc: 0.3870 - val_loss: 2.6255 - val_acc: 0.3264
# Epoch 22/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.2146 - acc: 0.3912 - val_loss: 2.6240 - val_acc: 0.3283
# Epoch 23/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.1964 - acc: 0.3945 - val_loss: 2.6231 - val_acc: 0.3287
# Epoch 24/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.1792 - acc: 0.3974 - val_loss: 2.6237 - val_acc: 0.3300
# Epoch 25/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.1591 - acc: 0.4010 - val_loss: 2.6261 - val_acc: 0.3291
# Epoch 26/50
# 2727/2729 [============================>.] - ETA: 0s - loss: 2.1447 - acc: 0.4034
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.1450 - acc: 0.4034 - val_loss: 2.6237 - val_acc: 0.3316
# Epoch 27/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.1099 - acc: 0.4147 - val_loss: 2.6229 - val_acc: 0.3329
# Epoch 28/50
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.1036 - acc: 0.4141 - val_loss: 2.6214 - val_acc: 0.3325
# Epoch 29/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.0946 - acc: 0.4165 - val_loss: 2.6232 - val_acc: 0.3329
# Epoch 30/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.0867 - acc: 0.4178 - val_loss: 2.6233 - val_acc: 0.3333
# Epoch 31/50
# 2727/2729 [============================>.] - ETA: 0s - loss: 2.0819 - acc: 0.4185
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.0819 - acc: 0.4185 - val_loss: 2.6243 - val_acc: 0.3340
# Epoch 32/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.0672 - acc: 0.4228 - val_loss: 2.6256 - val_acc: 0.3334
# Epoch 33/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.0601 - acc: 0.4248 - val_loss: 2.6268 - val_acc: 0.3334
# Epoch 34/50
# 2724/2729 [============================>.] - ETA: 0s - loss: 2.0529 - acc: 0.4263
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2729/2729 [==============================] - 8s 3ms/step - loss: 2.0529 - acc: 0.4263 - val_loss: 2.6276 - val_acc: 0.3353
# Epoch 35/50
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.0467 - acc: 0.4275 - val_loss: 2.6275 - val_acc: 0.3344
# Epoch 36/50
# 2718/2729 [============================>.] - ETA: 0s - loss: 2.0470 - acc: 0.4278Restoring model weights from the end of the best epoch.
# 2729/2729 [==============================] - 7s 3ms/step - loss: 2.0472 - acc: 0.4278 - val_loss: 2.6271 - val_acc: 0.3344
# Epoch 00036: early stopping
# Epoch 1/50
# 4593/4596 [============================>.] - ETA: 0s - loss: 4.6088 - acc: 0.0779WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4596/4596 [==============================] - 13s 3ms/step - loss: 4.6084 - acc: 0.0779 - val_loss: 3.9137 - val_acc: 0.0891
# Epoch 2/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.9461 - acc: 0.0836 - val_loss: 3.7403 - val_acc: 0.0949
# Epoch 3/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.7909 - acc: 0.0903 - val_loss: 3.6624 - val_acc: 0.0999
# Epoch 4/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.7146 - acc: 0.0944 - val_loss: 3.6140 - val_acc: 0.1028
# Epoch 5/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.6639 - acc: 0.0988 - val_loss: 3.5789 - val_acc: 0.1073
# Epoch 6/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.6271 - acc: 0.1023 - val_loss: 3.5506 - val_acc: 0.1103
# Epoch 7/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.5958 - acc: 0.1061 - val_loss: 3.5286 - val_acc: 0.1131
# Epoch 8/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.5703 - acc: 0.1098 - val_loss: 3.5100 - val_acc: 0.1152
# Epoch 9/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.5469 - acc: 0.1123 - val_loss: 3.4941 - val_acc: 0.1165
# Epoch 10/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.5289 - acc: 0.1140 - val_loss: 3.4807 - val_acc: 0.1173
# Epoch 11/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.5130 - acc: 0.1159 - val_loss: 3.4693 - val_acc: 0.1197
# Epoch 12/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.4968 - acc: 0.1184 - val_loss: 3.4590 - val_acc: 0.1201
# Epoch 13/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.4840 - acc: 0.1208 - val_loss: 3.4497 - val_acc: 0.1211
# Epoch 14/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.4726 - acc: 0.1217 - val_loss: 3.4407 - val_acc: 0.1225
# Epoch 15/50
# 4596/4596 [==============================] - 14s 3ms/step - loss: 3.4595 - acc: 0.1238 - val_loss: 3.4330 - val_acc: 0.1234
# Epoch 16/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.4481 - acc: 0.1253 - val_loss: 3.4263 - val_acc: 0.1249
# Epoch 17/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.4381 - acc: 0.1260 - val_loss: 3.4202 - val_acc: 0.1255
# Epoch 18/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.4270 - acc: 0.1269 - val_loss: 3.4140 - val_acc: 0.1265
# Epoch 19/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.4190 - acc: 0.1282 - val_loss: 3.4088 - val_acc: 0.1267
# Epoch 20/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.4113 - acc: 0.1296 - val_loss: 3.4032 - val_acc: 0.1277
# Epoch 21/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.4072 - acc: 0.1295 - val_loss: 3.3997 - val_acc: 0.1289
# Epoch 22/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.3981 - acc: 0.1303 - val_loss: 3.3950 - val_acc: 0.1297
# Epoch 23/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3895 - acc: 0.1328 - val_loss: 3.3907 - val_acc: 0.1296
# Epoch 24/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.3824 - acc: 0.1321 - val_loss: 3.3873 - val_acc: 0.1302
# Epoch 25/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3756 - acc: 0.1349 - val_loss: 3.3832 - val_acc: 0.1310
# Epoch 26/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.3708 - acc: 0.1358 - val_loss: 3.3794 - val_acc: 0.1319
# Epoch 27/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.3657 - acc: 0.1360 - val_loss: 3.3776 - val_acc: 0.1323
# Epoch 28/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3579 - acc: 0.1372 - val_loss: 3.3740 - val_acc: 0.1331
# Epoch 29/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3519 - acc: 0.1378 - val_loss: 3.3710 - val_acc: 0.1328
# Epoch 30/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.3458 - acc: 0.1385 - val_loss: 3.3689 - val_acc: 0.1334
# Epoch 31/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3398 - acc: 0.1386 - val_loss: 3.3656 - val_acc: 0.1342
# Epoch 32/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3347 - acc: 0.1411 - val_loss: 3.3641 - val_acc: 0.1340
# Epoch 33/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3306 - acc: 0.1404 - val_loss: 3.3616 - val_acc: 0.1348
# Epoch 34/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3245 - acc: 0.1432 - val_loss: 3.3590 - val_acc: 0.1347
# Epoch 35/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3208 - acc: 0.1429 - val_loss: 3.3571 - val_acc: 0.1350
# Epoch 36/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.3169 - acc: 0.1430 - val_loss: 3.3552 - val_acc: 0.1345
# Epoch 37/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.3138 - acc: 0.1448 - val_loss: 3.3541 - val_acc: 0.1356
# Epoch 38/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3057 - acc: 0.1463 - val_loss: 3.3521 - val_acc: 0.1360
# Epoch 39/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.3027 - acc: 0.1458 - val_loss: 3.3496 - val_acc: 0.1359
# Epoch 40/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.2988 - acc: 0.1468 - val_loss: 3.3485 - val_acc: 0.1365
# Epoch 41/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.2942 - acc: 0.1470 - val_loss: 3.3469 - val_acc: 0.1373
# Epoch 42/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.2890 - acc: 0.1470 - val_loss: 3.3449 - val_acc: 0.1369
# Epoch 43/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.2848 - acc: 0.1483 - val_loss: 3.3433 - val_acc: 0.1363
# Epoch 44/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.2815 - acc: 0.1480 - val_loss: 3.3425 - val_acc: 0.1369
# Epoch 45/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.2802 - acc: 0.1487 - val_loss: 3.3414 - val_acc: 0.1371
# Epoch 46/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.2737 - acc: 0.1492 - val_loss: 3.3402 - val_acc: 0.1372
# Epoch 47/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.2699 - acc: 0.1501 - val_loss: 3.3390 - val_acc: 0.1369
# Epoch 48/50
# 4596/4596 [==============================] - 12s 3ms/step - loss: 3.2672 - acc: 0.1507 - val_loss: 3.3379 - val_acc: 0.1371
# Epoch 49/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.2631 - acc: 0.1515 - val_loss: 3.3373 - val_acc: 0.1373
# Epoch 50/50
# 4596/4596 [==============================] - 13s 3ms/step - loss: 3.2593 - acc: 0.1516 - val_loss: 3.3361 - val_acc: 0.1373

# %%
game = pgn_games[6]
board = pgn_games[6].board()

print(np.argmax(prediction))
prediction = np.delete(prediction, 62)
print(np.argmax(prediction))


def top_valid_piece(prediction, board):
    

# for move in game.mainline_moves():
#     input_data = get_board_state(board) + [-1]
    
#     if board.ply() <= 14:
#         prediction = SaP_white_early.predict([input_data])
#     elif 15 <= board.ply() <= 40:
#         prediction = SaP_white_mid.predict([input_data])
#     else: 
#         prediction = SaP_white_late.predict([input_data])
    
#     prediction = prediction.reshape(8, 8)
#     plt.imshow(prediction, cmap='hot', interpolation='nearest')
#     print("Turn: ", board.ply(), "-----------")
#     plt.show()
#     print(move.from_square)
#     print(np.argmax(prediction))
#     print(move)
#     board.push(move)
# Out:
# 63
# 62

# %%
print(first_game.headers)
# Out:
# Headers(Event='FICS rated standard game', Site='FICS freechess.org', Date='2020.12.31', Round='?', White='AlphaWolfKing', Black='exeComp', Result='0-1', BlackClock='0:15:00.000', BlackElo='2708', BlackIsComp='Yes', BlackRD='0.0', ECO='B20', FICSGamesDBGameNo='490001485', PlyCount='70', Time='22:05:00', TimeControl='900+5', WhiteClock='0:15:00.000', WhiteElo='1307', WhiteRD='0.0')
